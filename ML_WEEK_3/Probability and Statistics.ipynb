# %%
# 1. Write a program to find probability of drawing an ace from pack of cards

ace = 4
cards = 52
Probability_result = ace / cards
print("Probability of ace from deck of cards:", round(Probability_result,2))
# Out:
# Probability of ace from deck of cards: 0.08

# %%
# 2. Write a program to find the probability of drawing an ace after drawing a king on the first draw

def event_probability(event_outcomes, sample_space):
    probability = (event_outcomes / sample_space) * 100
    return round(probability, 2)

cards = 52
cards_drawn = 1 
cards = cards - cards_drawn 
aces = 4
ace_probability1 = event_probability(aces, cards)
print("probability of drawing an ace after drawing a king on the first draw: ",ace_probability1)
# Out:
# probability of drawing an ace after drawing a king on the first draw:  7.84

# %%
# 3. Write a program to find the probability of drawing an ace after drawing an ace on the first draw

def event_probability(event_outcomes, sample_space):
    probability = (event_outcomes / sample_space) * 100
    return round(probability, 2)

aces_drawn = 1
aces = 4
cards = 52
aces = aces - aces_drawn
ace_probability2 = event_probability(aces, cards)
print("probability of drawing an ace after drawing an ace on the first draw: ",ace_probability2)
# Out:
# probability of drawing an ace after drawing an ace on the first draw:  5.77

# %%
# 4.You toss a fair coin three times write a program to find following:


Probabilities = [ 'HHH', 'HHT', 'HTH', 'THH', 'HTT', 'THT', 'TTH', 'TTT' ]
print("\n All Probability", Probabilities)
len_Probabilities = len(Probabilities)
print("\n length of Probability: ", len_Probabilities)

# 1.What is the probability of three heads, HHH? 
def A():
    HHH_Probabilities = Probabilities.count('HHH')
    print("\n count of HHH Probabilities :", HHH_Probabilities)
    HHH_Result = HHH_Probabilities / len_Probabilities
    print("\n probability of three heads : ",  round(HHH_Result,2))
    print("_______________________________________________")


#2.What is the probability that you observe exactly one heads?"""
def B():
    list1 = [ ]
    for temp in Probabilities :
        count = 0
        for char in temp :
            if char == 'H' :
                count += 1
        if count == 1 :
            list1.append(temp)
    length_OneHead = len(list1)

    print("\n one Head ", length_OneHead)
    prob_oneH = length_OneHead / len_Probabilities
    print("\n probability of exactly one heads",round(prob_oneH,2))
    print("____________________________________________________")

#3.Given that you have observed at least one heads, what is the probability that you observe at least two heads?

def C():
    
    count_TTT = Probabilities.count('TTT')
    print("\n count of TTT", count_TTT)
    one_Head = (len_Probabilities - count_TTT) / len_Probabilities

    at_least_one = one_Head

    list = [ ]
    for temp in Probabilities :
        count = 0
        for char in temp :
            if char == 'H' :
                count += 1
        if count >= 2 :
            list.append(temp)
    len_atleasttwo = len(list)
    print("\n Two Head ", len_atleasttwo)
    result = len_atleasttwo / len_Probabilities

    at_least_two = result
    result = at_least_two / at_least_one
    print("\n probability at least two heads", round(result,2))

flag = True

print("1.What is the probability of three heads, HHH?")
print("2.What is the probability that you observe exactly one heads?")
print("3.Given that you have observed at least one heads, what is the probability that you observe at least two heads?")
print("0. exit")
while flag :

    try :

        print('____________________________________')

        choice = int(input("Enter your choice"))

        if choice == 0 :
            flag = False

        elif choice == 1 :
            A()

        elif choice == 2 :
            B()

        elif choice == 3 :
            C()
        else :
            print("\nenter input within 1-3 choice")
    except Exception as e :
        print(e)
# Out:
#  All Probability ['HHH', 'HHT', 'HTH', 'THH', 'HTT', 'THT', 'TTH', 'TTT']
#
#  length of Probability:  8
# 1.What is the probability of three heads, HHH?
# 2.What is the probability that you observe exactly one heads?
# 3.Given that you have observed at least one heads, what is the probability that you observe at least two heads?
# 0. exit
# ____________________________________
# Enter your choice1
#
#  count of HHH Probabilities : 1
#
#  probability of three heads :  0.12
# _______________________________________________
# ____________________________________
# Enter your choice2
#
#  one Head  3
#
#  probability of exactly one heads 0.38
# ____________________________________________________
# ____________________________________
# Enter your choice3
#
#  count of TTT 1
#
#  Two Head  4
#
#  probability at least two heads 0.57
# ____________________________________
# Enter your choice0

# %%
"""5. In my town, it's rainy_para one third of the days. Given that it is rainy_para, there will be heavy
traffic with probability 12, and given that it is not rainy_para, there will be heavy traffic with probability
14. If it's rainy_para and there is heavy traffic, I arrive late for work with probability 12. On the other
hand, the probability of being late is reduced to 18 if it is not rainy_para and there is no heavy traffic.
In other situations (rainy_para and no traffic, not rainy_para and traffic) the probability of being late is 0.25.
You pick a random day."""


rainy_para = 1 / 3
rainy_with_Traffic = 1 / 2
rainy_withTraffic_late = 1 / 2
rainy_withTraffic_Nolate = 1 / 2

rainy_with_NoTraffic = 1 / 2
rainy_with_NoTraffic_late = 1 / 4
rainy_with_NoTraffic_Nolate = 3 / 4

not_rainy = 2 / 3
not_rainy_with_Traffic = 1 / 4
not_rainy_with_Traffic_late = 1 / 4
not_rainy_with_Traffic_Nolate = 3 / 4

not_rainy_with_NoTraffic = 3 / 4
not_rainy_with_NoTraffic_late = 1 / 8
not_rainy_with_NoTraffic_Nolate = 7 / 8

#"1. What is the probability that it's not raining and there is heavy traffic and I am not late?"

def rainy():
    probability = not_rainy * not_rainy_with_Traffic * not_rainy_with_Traffic_Nolate
    print("probability that no raining, heavy traffic,not late: ", round(probability,2))


#"2. What is the probability that I am late?"
def late():
    rainy_withTraffic_late1 = rainy_para * rainy_with_Traffic * rainy_withTraffic_late
    rainy_with_NoTraffic_late1 = rainy_para * rainy_with_NoTraffic * rainy_with_NoTraffic_late
    not_rainy_with_Traffic_late1 = not_rainy * not_rainy_with_Traffic * not_rainy_with_Traffic_late
    not_rainy_with_NoTraffic_late1 = not_rainy * not_rainy_with_NoTraffic * not_rainy_with_NoTraffic_late

    result = rainy_withTraffic_late1 + rainy_with_NoTraffic_late1 \
                     + not_rainy_with_Traffic_late1 + not_rainy_with_NoTraffic_late1

    print("probability that I am late:", round(result,2))
    return result

#"3.Given that I arrived late at work, what is the probability that it rained that day?"
def rained_that_day():
    rainy_withTraffic_late1 = rainy_para * rainy_with_Traffic * rainy_withTraffic_late
    rainy_with_NoTraffic_late1 = rainy_para * rainy_with_NoTraffic * rainy_with_NoTraffic_late
    prob_late1 = late()
    print("probability that it rained that day:", round(rainy_withTraffic_late1 + rainy_with_NoTraffic_late1/ prob_late1,2))

flag = True

print("1. What is the probability that it's not raining and there is heavy traffic and I am not late?")
print("2. What is the probability that I am late?")
print("3.Given that I arrived late at work, what is the probability that it rained that day?")
print("0. exit")

while flag :

    try :

        print('____________________________________')

        choice = int(input("Enter your choice"))

        if choice == 0 :
            flag = False

        elif choice == 1 :

             rainy()

        elif choice == 2 :
            x=late()

        elif choice == 3 :
            rained_that_day()

        else :
            print("\nenter input within 1-3 choice")
    except Exception as e :
        print(e)
# Out:
# 1. What is the probability that it's not raining and there is heavy traffic and I am not late?
# 2. What is the probability that I am late?
# 3.Given that I arrived late at work, what is the probability that it rained that day?
# 0. exit
# ____________________________________
# Enter your choice1
# probability that no raining, heavy traffic,not late:  0.12
# ____________________________________
# Enter your choice2
# probability that I am late: 0.23
# ____________________________________
# Enter your choice3
# probability that I am late: 0.23
# probability that it rained that day: 0.27
# ____________________________________
# Enter your choice0

# %%
# 6. Given the following statistics, write a program to find the probability that a woman has
# cancer if she has a positive mammogram result?
# a. One percent of women over 50 have breast cancer.
# b. Ninety percent of women who have breast cancer test positive on mammograms.
# c. Eight percent of women will have false positives.

cancer = 0.01
no_cancer = 0.99
test_positive = 0.9
false_positive = 0.08

Probability = (cancer * test_positive) /( (cancer * test_positive) + (no_cancer * false_positive))
print("Probability of women has cancer, if she has positive mammogram result:\n", round(Probability,4))
# Out:
# Probability of women has cancer, if she has positive mammogram result:
#  0.102

# %%
# 7. A bank teller serves customers standing in the queue one by one. Suppose that the service time XiXi for 
# customer ii has mean EXi=2 (minutes) and Var(Xi)=1. We assume that service times for different bank customers are independent. 
# Let YY be the total time the bank teller spends serving 50 customers. Write a program to find P(90<Y<110)

import math

Total = 50
value_one = 90
Value_two = 110
mean = 2
deviation = 1

    # by using central limit theorem we are calculating probability
prob_value_one = ((value_one - (Total * mean)) / (math.sqrt(Total) * deviation))
print("prob_value_one:(90) ",prob_value_one)
prob_value_two = ((Value_two - (Total * mean)) / (math.sqrt(Total) * deviation))
print("prob_value_two:(110) ",prob_value_two)

result = result = prob_value_two - prob_value_one
print("Result : ",result)
# Out:
# prob_value_one:(90)  -1.414213562373095
# prob_value_two:(110)  1.414213562373095
# Result :  2.82842712474619

# %%
# 8. In a communication system each data packet consists of 1000 bits. Due to the noise,
# each bit may be received in error with probability 0.1. It is assumed bit errors occur independently.
# Find the probability that there are more than 120 errors in a certain data packet.

import math
def prob(l_mean, l_standard_deviation, l_n, l_x):
    z_score = (l_x - l_mean) / (l_standard_deviation * (math.sqrt(l_n)))
    return z_score


g_p = 0.1
g_n = 1000
g_mean = g_n * g_p
g_standard_deviation = math.sqrt((g_p * (1 - g_p)))
print("Standard_deviation: ",g_standard_deviation)
print("Mean: ", g_mean)
g_x = 120


print("Z_score: ",prob(g_mean, g_standard_deviation, g_n, g_x))
z = (1 - 0.9821)
print("Probability = ", z)
# Out:
# Standard_deviation:  0.30000000000000004
# Mean:  100.0
# Z_score:  2.1081851067789192
# Probability =  0.017900000000000027

# %%
# 9. In a particular pain clinic, 10% of patients are prescribed narcotic pain killers. Overall,
# five percent of the clinic’s patients are addicted to narcotics (including pain killers and illegal substances). 
# Out of all the people prescribed pain pills, 8% are addicts. If a patient is an addict, 
# write a program to find the  probability that they will be prescribed pain pills?

pain_killers = 0.1           # 10% of patients are prescribed narcotic pain killers
addicted = 0.05              # five percent of the clinics patients are addicted to narcotics
addict_getting_pills = 0.08  # all the people prescribed pain pills, 8% are addicts
probability_result = (addict_getting_pills * pain_killers) / addicted
print("Probability of that prescribed pain pills:", probability_result)
# Out:
# Probability of that prescribed pain pills: 0.16

# %%
# 10. X is a normally normally distributed variable with mean μ = 30 and standard
# deviation σ = 4. Write a program to find
# a. P(x < 40)
# b. P(x > 21)
# c. P(30 < x < 35)


class Normal_distributed():

    def __init__(self):
        self.num_one = 40
        self.mean = 30
        self.standard_deviation = 4
        self.total_area = 1
        self.num_two = 21
        self.num_three = 30
        self.num_four = 35
        self.z_1 = 0.9938
        self.z_2 = 0.0122
        self.z_3 = 0.8944

    # 1st problem:P(x < 40)
    def Z_value_first(self) :
        Z_value = (self.num_one - self.mean) / self.standard_deviation
        print("Z_value is =  ", Z_value)
        if Z_value <= 2.5 :
            print("% area of left side:", self.z_1*100)

    # 2nd problem:P(x > 21)
    def Z_value_second(self):
        Z_value = (self.num_two - self.mean) / self.standard_deviation
        print("Z_value is = ", Z_value)
        if Z_value <= -2.25 :
            print("% area of left side:", self.z_2*100)
            area = self.z_2 - self.total_area
            print("total area:", area)

    # 3rd problem: P(30 < x < 35)
    def Z_value_third(self) :
        Z_value_one = (self.num_three - self.mean) / self.standard_deviation
        print("Z_value_first is = ", Z_value_one)
        Z_value_two = (self.num_four - self.mean) / self.standard_deviation
        print("Z_value_second is = ", Z_value_two)
        if Z_value_one < 1.25 :
            area_half = 0.5
            print("% area of left side:", self.z_3*100)
            total_area = self.z_3 - area_half
            print("total area:", total_area)


obj = Normal_distributed()

flag = True

print("1.program to find : P(x < 40) ")
print("2.program to find : P(x > 21). ")
print("3.program to find :  P(30 < x < 35)")
print("0. exit")

while flag :

    try :

        print('____________________________________')

        choice = int(input("Enter your choice"))

        if choice == 0 :
            flag = False

        elif choice == 1 :

            obj.Z_value_first()

        elif choice == 2 :
            obj.Z_value_second()

        elif choice == 3 :
            obj.Z_value_third()

        else :
            print("\nenter input within 1-3 choice")
    except Exception as e :
        print(e)
# Out:
# 1.program to find : P(x < 40)
# 2.program to find : P(x > 21).
# 3.program to find :  P(30 < x < 35)
# 0. exit
# ____________________________________
# Enter your choice1
# Z_value is =   2.5
# % area of left side: 99.38
# ____________________________________
# Enter your choice2
# Z_value is =  -2.25
# % area of left side: 1.22
# total area: -0.9878
# ____________________________________
# Enter your choice3
# Z_value_first is =  0.0
# Z_value_second is =  1.25
# % area of left side: 89.44
# total area: 0.3944
# ____________________________________
# Enter your choice0

# %%
# 11. A radar unit is used to measure speeds of cars on a motorway. 
# The speeds are normally distributed with a mean of 90 km/hr and a standard deviation of 10 km/hr. 
# Write a program to find the probability that a car picked at random is travelling at more than 100 km/hr? 

mean = 90
standard_deviation = 10
Normal_speed = 100
z_area = 0.8413

Z_value = (Normal_speed - mean) / standard_deviation
print("Z_value is:", Z_value)
print("probability that a car picked at random is travlling at more than 100km/hr:", round(Z_value - z_area,2))
# Out:
# Z_value is: 1.0
# probability that a car picked at random is travlling at more than 100km/hr: 0.16

# %%
# 12.  Write a program to find the probability of getting a random number from the interval [2, 7]
import random

interval_difference = 5
num = random.randint(2, 7)
print("random number is ", num)
result = num / interval_difference
print("probability of getting a random number", round(result,2))
# Out:
# random number is  5
# probability of getting a random number 1.0

# %%
#13. The table below shows the height, x, in inches and the pulse rate, y, per minute
#    for 9 people. Write a program to find the correlation coefficient and interpret your result.
#    x ⇒ 68 72 65 70 62 75 78 64 68
#    y ⇒ 90 85 88 100 105 98 70 65 72


import math


def correlation_Coefficient(X, Y, n):

    sum_X = 0
    sum_Y = 0
    sum_XY = 0
    squareSum_X = 0
    squareSum_Y = 0

    i = 0
    while i < n:
        # sum of elements of array X.
        sum_X = sum_X + X[i]

        # sum of elements of array Y.
        sum_Y = sum_Y + Y[i]

        # sum of X[i] * Y[i].
        sum_XY = sum_XY + X[i] * Y[i]

        # sum of square of array elements.
        squareSum_X = squareSum_X + X[i] * X[i]
        squareSum_Y = squareSum_Y + Y[i] * Y[i]

        i = i + 1
    #Print Result:
    print("sum of list X is:", sum_X)
    print("sum of list Y is:", sum_Y)
    print("summation of X and Y is:", sum_XY)
    # using calculating correlation formula
    correlation_result = float(n * sum_XY - sum_X * sum_Y) / float(math.sqrt((n * squareSum_X - sum_X * sum_X) * (n * squareSum_Y - sum_Y * sum_Y)))
    print("correlation_coefficient result is:", correlation_result)


list_X = [68, 72, 65, 70, 62, 75, 78, 64, 68]
list_y = [90, 85, 88, 100, 105, 98, 70, 65, 72]

# Find the size of array.
n = len(list_X)
print("length of list:", n)
# Function call
correlation_Coefficient(list_X, list_y, n)
# Out:
# length of list: 9
# sum of list X is: 622
# sum of list Y is: 773
# summation of X and Y is: 53336
# correlation_coefficient result is: -0.14614402427021678
